# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import healpy as hp

# %%
NSIDE = 512
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
# Out:
# Approximate resolution at NSIDE 512 is 0.11 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 3145728

# %%
ori = np.loadtxt("./earth_1Mhz/B_original.txt")

# %%
hp.mollview(ori, nest=True, title="Mollview image B with NSIDE=512")
hp.graticule()  # 添加经纬线
plt.show()

# %%
total_data = np.loadtxt("./wsnoblockage/C1day1M.txt")

# 读取并累加30个文件
for i in range(2, 451):
    file_path = f"./wsnoblockage/C{i}day1M.txt"
    data = np.loadtxt(file_path)
    total_data += data

hp.mollview(total_data, nest=True, title="Mollview image healpix No Blockage with NSIDE=512")
hp.graticule()  # 添加经纬线
plt.show()

# %%
hp.mollview(total_data, nest=True, title="Mollview image healpix No Blockage with NSIDE=512")
hp.graticule()  # 添加经纬线
plt.show()
